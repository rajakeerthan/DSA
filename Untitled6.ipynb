# %% [markdown]
# <a href="https://colab.research.google.com/github/rajakeerthan/DSA/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import nltk
nltk.download('punkt')
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
ps = PorterStemmer()
ps

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-320a93c6-c5cf-4fab-a863-7283f22a9093" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-320a93c6-c5cf-4fab-a863-7283f22a9093">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# import libraries
df = pd.read_csv("s1.txt",delimiter=' ')
df.to_csv('texting.csv')
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
import io
from gensim.parsing.preprocessing import remove_stopwords
new=""
import csv
with open('texting.csv', 'rU') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        if row == []:
            continue
        else:
           # print(row)
            row1=""
            for z in row:
                row1=row1+" "+z
            new=new+row1
#print(new)
filtered_sentence = remove_stopwords(new)
#print("*****************************no stopwords**********************************************************************")
#print(filtered_sentence)
tokens=word_tokenize(filtered_sentence.lower())
#print("******************************tokenized***************************************************************************")
#print(tokens)
stemmer = PorterStemmer()
porter_stemmed = [stemmer.stem(token) for token in tokens]
#print("************************************stemmed**************************************************************")
#print(porter_stemmed)
#print(len(porter_stemmed))
lines=porter_stemmed
unique_words = set(porter_stemmed)
#print("****************************UNIQUE WORDS***********************************************************")
# Convert the set back to a list
unique_words_list = list(unique_words)
#print(unique_words_list)
#print("legth is",len(unique_words_list))
# Out:
#   keerthana is good girl. 0 pooja bad boy.  1 lavanya is laughing.
# *****************************no stopwords**********************************************************************
# keerthana good girl. 0 pooja bad boy. 1 lavanya laughing.
# ******************************tokenized***************************************************************************
# ['keerthana', 'good', 'girl', '.', '0', 'pooja', 'bad', 'boy', '.', '1', 'lavanya', 'laughing', '.']
# ************************************stemmed**************************************************************
# ['keerthana', 'good', 'girl', '.', '0', 'pooja', 'bad', 'boy', '.', '1', 'lavanya', 'laugh', '.']
# 13
# ****************************UNIQUE WORDS***********************************************************
# ['boy', 'good', '1', 'pooja', 'bad', '.', 'lavanya', '0', 'girl', 'laugh', 'keerthana']
# legth is 11
# <ipython-input-18-4b4afc8ee9c1>:12: DeprecationWarning: 'U' mode is deprecated
# ...

# %%
headings =unique_words_list
c=0
with open('empty.csv', 'w', newline='') as file:
  # Create a CSV writer object
  writer = csv.writer(file)

  # Write the headings to the file
  writer.writerow(headings)
rows = []
string_sent=[]
with open('texting.csv', 'r') as f, open('empty.csv', 'a', newline='') as output_file:
    # Read the file into a list of lists
    rows = list(csv.reader(f))
    writer = csv.writer(output_file)
    # Iterate over the rows in the list
    for row in rows:
        # Convert the row to a string
        row_string = ','.join(row)

        # Do something with the row string
        #print(row_string)
        string_sent.append(row_string)
        c=c+1
# Out:
# ,keerthana,is,good,girl.
# 0,pooja,bad,boy.,
# 1,lavanya,is,laughing.,

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c150441-f713-4d19-b95b-4d78c3f6f1ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c150441-f713-4d19-b95b-4d78c3f6f1ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("kk.txt",delimiter=' ')
df.to_csv('k.csv')
import csv
qq=""
with open('k.csv', 'rU') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        if row == []:
            continue
        else:
           # print(row)
            row1=""
            for z in row:
                row1=row1+" "+z
            qq=qq+row1
#print(qq)
filtered_sentence = remove_stopwords(qq)
#print("*****************************no stopwords**********************************************************************")
#print(filtered_sentence)
tokens=word_tokenize(filtered_sentence.lower())
#print("******************************tokenized***************************************************************************")
#print(tokens)
stemmer = PorterStemmer()
porter_stemmed = [stemmer.stem(token) for token in tokens]
#print("************************************stemmed**************************************************************")
#print(porter_stemmed)
#print(len(porter_stemmed))
unique_words = set(porter_stemmed)
ques=""
for x in unique_words:
  ques=ques+" "+x
#print(ques)
listing=[]
with open('empty.csv', 'r') as output_file:
	# creating a csv reader object
      for j in range(0,len(headings)):
            if headings[j] in ques:
                listing.append(1)
            else:
                listing.append(0)
     # print(listing)
      output_file.close()
#for j in range(0,len(headings)):
 #   print(listing[j])
max=0
max_list=""
#print("solution is ",max)
#print(max_list)
from csv import writer
with open('empty.csv', 'a', newline='') as output_file:
	# creating a csv reader object
  for i in range(0,len(string_sent)):
      listing1=[]
      count=0
      for j in range(0,len(headings)):
            if headings[j] in string_sent[i]:
                listing1.append(1)
            else:
                listing1.append(0)
      for x,y in zip(listing1,listing):
        if str(x)==str(y):
                  count+=1
      if(max<count):
          max=count
          max_list=string_sent[i]


  output_file.close()
#print("solution is ",max)
max_list=max_list.replace(',',' ')
#print(max_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e6ac8b786ff4> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("kk.txt",delimiter=' ')
#       4 df.to_csv('k.csv')
#       5 import csv
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
